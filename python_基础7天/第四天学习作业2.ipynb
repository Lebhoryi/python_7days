# %%
'''
文件名称：第四天学习第三次作业2    项目练习:《扶摇》之演员简介

摘要：补上第三次作业1和2

版本：v0.0.1

作者：Lebhoryi
时间：20180922
'''

# 创建一个字典
# 包括演员名字,饰演角色,配音，演员。
Fuyao_Actor_Profile = {
    
    "杨幂" :
        {
        "饰演角色" : "扶摇",
        "配音" : "王潇倩",
        },
    
    "阮经天" :
        {
        "饰演角色" : "长孙无极",
        "简介" : "天权国太子",
        "配音" : "马正阳",
        },
    
    "刘奕君" :
        {
        "饰演角色" : "齐震",
        "简介" : "太渊国国公",
        "配音" : "刘奕君",
        },
    
    "高伟光" :
        {
        "饰演角色" : "战北野",
        "简介" : "天煞烈王",
        "配音" : "赵成晨",
        }, 
    
    "王劲松" :
        {
        "饰演角色" : "长孙迥",
        "简介" : "天权国皇帝",
        "配音" : "王劲松",
        }, 
    
    "黄宥明" :
        {
        "饰演角色" : "燕惊尘",
        "简介" : "玄元剑派大师兄",
        "配音" : "文森",
        }, 
    
    "高瀚宇" :
        {
        "饰演角色" : "江枫",
        "简介" : "长孙无极的贴身密卫",
        "配音" : "袁聪宇",
        },   
    
    "顾又铭" :
        {
        "饰演角色" : "战北恒",
        "简介" : "天煞国恒王",
        "配音" : "林强",
        }, 
    
    "秦焰" :
        {
        "饰演角色" : "周叔",
        "配音" : "宣晓鸣",
        }, 
    
    "蒋龙" :
        {
        "饰演角色" : "小七",
        "配音" : "苏尚卿",
        }, 

}

# %%
# 打印出杨幂扮演的角色是谁
# print(Fuyao_Actor_Profile["杨幂"]["饰演角色"])
print("杨幂扮演的角色是{}。".format(Fuyao_Actor_Profile["杨幂"]["饰演角色"]))

# 创建一个备份字典
Copy_Fuyao = Fuyao_Actor_Profile
# Out:
# 杨幂扮演的角色是扶摇。

# %%
# 去除阮经天，更换为陈晓
Fuyao_Actor_Profile.update(陈晓 = Fuyao_Actor_Profile.pop("阮经天"))
# print(Fuyao_Actor_Profile)
# Out:
# {'杨幂': {'饰演角色': '扶摇', '配音': '王潇倩'}, '刘奕君': {'饰演角色': '齐震', '简介': '太渊国国公', '配音': '刘奕君'}, '高伟光': {'饰演角色': '战北野', '简介': '天煞烈王', '配音': '赵成晨'}, '王劲松': {'饰演角色': '长孙迥', '简介': '天权国皇帝', '配音': '王劲松'}, '黄宥明': {'饰演角色': '燕惊尘', '简介': '玄元剑派大师兄', '配音': '文森'}, '高瀚宇': {'饰演角色': '江枫', '简介': '长孙无极的贴身密卫', '配音': '袁聪宇'}, '顾又铭': {'饰演角色': '战北恒', '简介': '天煞国恒王', '配音': '林强'}, '秦焰': {'饰演角色': '周叔', '配音': '宣晓鸣'}, '蒋龙': {'饰演角色': '小七', '配音': '苏尚卿'}, '陈晓': {'饰演角色': '长孙无极', '简介': '天权国太子', '配音': '马正阳'}}

# %%
# 增加新的角色,三种方法
# 第一种 dict[key] = value
# 第二种 两个字典拼接 dictMerged2=dict(dict1, **dict2)
# 第三种 dict1.setdefault(key, value)  
new_actor_profiel = {
    "张雅钦" :
        {
        "饰演角色" : "雅兰珠",
        "简介" : "邛叶公主",
        "配音" : "吟良犬",
        }, 
    
    "王鹤润" :
        {
        "饰演角色" : "凤净梵",
        "简介" : "璇玑国二王女",
        "配音" : "蔡娜",
        }, 
    
    "周俐葳" :
        {
        "饰演角色" : "时岚",
        "简介" : "扶摇假扮宇文紫时的婢女",
        "配音" : "张晗",
        }, 
    
    "魏晖倪" :
        {
        "饰演角色" : "简雪",
        "简介" : "太渊国德夫人",
        "配音" : "曹一茜",
        },
}

Fuyao_Actor_Profile = dict(Fuyao_Actor_Profile, **new_actor_profiel)

# %%
# print(Fuyao_Actor_Profile)
# 打印出阮经天所在的演员字典中的演员名以及角色名,并统计 一个有多少个角色。
i = 0
for key,value in Copy_Fuyao.items():
    # iteritems: an iterator over the (key, value) items
    print("演员是{}； 角色是{}。".format(key, value["饰演角色"]))
#     print("角色是{}.".format(value["饰演角色"]))
    i = i + 1
print("一共有{}个角色。".format(i))
# Out:
# 演员是杨幂； 角色是扶摇。
# 演员是刘奕君； 角色是齐震。
# 演员是高伟光； 角色是战北野。
# 演员是王劲松； 角色是长孙迥。
# 演员是黄宥明； 角色是燕惊尘。
# 演员是高瀚宇； 角色是江枫。
# 演员是顾又铭； 角色是战北恒。
# 演员是秦焰； 角色是周叔。
# 演员是蒋龙； 角色是小七。
# 演员是陈晓； 角色是长孙无极。
# 一共有10个角色。

# %%
# 重新创建一个新的字典存放以下信息:扶摇的名字,喜欢她的男角色有(长孙无极、
# 战北野、小七),去过的国家(太渊、天权、天煞、璇玑)
fuyao_single = { 
    "扶摇" :
    {
        "喜欢她的男角色有：" : ["长孙无忌", "战北野", "小七"],
        "她去过的国家：" : ["太渊", "天权", "天煞", "璇玑"],
    }
    
}

print(fuyao_single)
# Out:
# {'扶摇': {'喜欢她的男角色有：': ['长孙无忌', '战北野', '小七'], '她去过的国家：': ['太渊', '天权', '天煞', '璇玑']}}
