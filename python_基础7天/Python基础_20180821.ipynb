# %% [markdown]
# # 1.第一次作业
# 打印Hello，World
#
# 来自第二天，三剑客

# %%
# 导入numpy
import numpy

# %%
# 打印Hello，world
print("Hello,world~")
# Out:
# Hello,world~

# %%
# format用法举例
print("我参加的是{}，希望圈子越来越好".format('python实战圈'))
# Out:
# 我参加的是python实战圈，希望圈子越来越好

# %% [markdown]
# # 2.第二次作业
# 来自第三天，夯实python基础
#
# 主要包括：
# * 数据类型
# * 注释
# * 常量与变量
#
# ## 2.1 数据类型
# 　大范围分布为数字，字符串，布尔型，和其他。
# 　这一点和c、c++区别有点大，把浮点型统统划到了数字类型。
#
# ## 2.2注释
# 　注释很重要，很重要，很重要，强调三遍，无论老鸟还是菜鸟。
# 　具体可分为行注释，块注释，类和函数注释，文档字符串等等，举个例子：
# <center>![image.png](attachment:image.png)</center>
#
# 　详细可参考这篇文章：
# 　"Python风格规范"（来自Google）
#
# 　链接：https://zh-google-styleguide.readthedocs.io/en/latest/google-python-styleguide/python_style_rules/
#
# ## 2.3常量和变量
# 　相信有点c基础的同学都会有所了解，略看。
#
# 　关于深拷贝和浅拷贝的概念自己还有些模糊。
#
# 　重点看了**字符串的常见运算**中的“使用方法修改字符串的大小写” 和“字符串分割”。
#
# 　其他的都在廖雪峰老师的网站上实现过，代码不再跟着敲一遍了。

# %% [markdown]
# # 3.第三次作业１
# 　《延禧攻略》之魏璎珞请客
#
# 　（来自 第四天，python数据结构，很多#####下面的代码是拓展）
#
# 　 图片中出现的链接：https://morvanzhou.github.io/tutorials/python-basic/basic/13-04-copy/
#
# * 目的：理解列表和字典
#
# ## 3.1 数据结构
#
# 　将各种数据通过某种方式排列组合在一起的结构，叫做数据结构。跟数据有关，形成结构体。
#
# 　举例： list，元组，dict，numpy中的array，tensorflow中的tensor
#
# ### 3.2 列表
#
# 　对象，函数，方法
#
# ### 3.3 列表方法
#
# 　copy(),sort(),count(),insert(),reverse()
#
# ### 3.4 其他
#
# 　过了凌晨12点了，其他部分的代码不再详细敲一遍。之前有敲过，这里复述个大概
#
# 　列表切片； 类型互换； join(); index(); len()
#
# 　元组，和列表最大的区别就是不能被修改，如果没记错的话，元组里面有列表成员的话，列表是可以进行修改的
#
# 　字典，key-values，字典的一些常用方法，增加删除等

# %%
# 定义一个列表
# 列表可修改，比如增加删除成员，按照序列提取成员
names_python_pc = ['陈升', '杨幂', '刘德华', 'Tfboys']
print('Python实战的成员有 : {}'.format(names_python_pc))

###################################################################
# 依次打印出name_python_pc这个列表,初学者建议用1，我在复习123

# 1.直接输出
# for i in names_python_pc:
#     print(i)
# 2.iter() 函数用来生成迭代器
# for i in iter(names_python_pc):
#     print(i)
# 3.enumerate(),遍历数据并自动计数
for counters,values in enumerate(names_python_pc):
    print(counters,values)
# Out:
# Python实战的成员有 : ['陈升', '杨幂', '刘德华', 'Tfboys']
# 0 陈升
# 1 杨幂
# 2 刘德华
# 3 Tfboys

# %%
# 查看变量类型
print('names_python_pc的数据类型是：{}'.format(type(names_python_pc)))

###################################################################
# 初学者建议用type(list)来查看list的属性，
# 有过python编程经历的推荐isinstance(对象，list)，返回值是布尔值
print(isinstance(names_python_pc,list))
print(isinstance(names_python_pc,tuple))
print(isinstance(names_python_pc,dict))
# Out:
# names_python_pc的数据类型是：<class 'list'>
# True
# False
# False

# %%
# 返回列表元素
print('names_python_pc的成员第1位是：{}'.format(names_python_pc[0]))
print('names_python_pc的成员最后两位是：{}'.format(names_python_pc[:-2]))
print('names_python_pc的成员第三位是：{}'.format(names_python_pc[2]))

# 修改第二位成员的名字
names_python_pc[1] = '扶摇'
print('names_python_pc的修改后的成员列表：{}'.format(names_python_pc))

# 添加列表，两种，insert，append。习惯用append，此处省去insert的代码
names_python_pc.append('皇上')
names_python_pc.append('皇后')
print('names_python_pc的成员末尾增加成员“皇上”，“皇后”，并显示：{}'.format(names_python_pc))
# Out:
# names_python_pc的成员第1位是：陈升
# names_python_pc的成员最后两位是：['陈升', '扶摇']
# names_python_pc的成员第三位是：刘德华
# names_python_pc的修改后的成员列表：['陈升', '扶摇', '刘德华', 'Tfboys']
# names_python_pc的成员末尾增加成员“皇上”，“皇后”，并显示：['陈升', '扶摇', '刘德华', 'Tfboys', '皇上', '皇后']

# %%
# 删除列表元素，del，pop，remove，
# del删除的对象不能再次被赋值给新的对象，pop可以再次被赋值给新的对象
# remove一次删一个值，若有相同元素，一次还是删一个

names_python_pc = ['陈升', '扶摇', '刘德华', 'Tfboys', '皇上', '皇后']
del names_python_pc[0] # 不能赋值给新的对象
have_pop_name = names_python_pc.pop() # 能赋值给新的对象
# print('have_pop_name:{}'.format(have_pop_name))
names_python_pc.remove('Tfboys')
print("删除了第一位成员还有{}和{}之后的names_python_pc：{}".format(have_pop_name,
        have_remove_name,names_python_pc))
# Out:
# 删除了第一位成员还有皇后和None之后的names_python_pc：['扶摇', '刘德华', '皇上']

# %%
# 列表方法
"""
copy方法复制一个物理对象，而非视图对象；
count方法计数；
index方法返回索引位置；
reverse方法实现元素颠倒；
sort方法排序；

list.sort() 是永久排序
sorted(list) 是临时排序
"""

L1 = ['a','a','b','c','d','e','f','g']
L2 = L1
print('sorted(L1): {}'.format(sorted(L1)))
print('L1: {}'.format(L1))
print("复制列表：{}".format(L2))
print('统计列表中a出现了{}次'.format(L2.count('a')))
print('B所在的位置{}'.format(L1.index('b'))) #反为b的索引位子
L1.reverse()
print('颠倒元素的顺序:{}'.format(L1))
L1.sort()
print('升序排列元素{}'.format(L1))
L1.sort(reverse=True) #降序
print('降序排列元素{}'.format(L1))

###################################################################
import copy
# 最终决定的是对象对应的id，具体可百度搜索莫烦，Ptyhon基础的copy & deepcopy 浅复制 & 深复制
# 链接：https://morvanzhou.github.io/tutorials/python-basic/basic/13-04-copy/
# 深拷贝,L2变，L3变
L3 = L1
# 第一层浅拷贝，L2=[1, 2, [3333, 4]]，改变L2[2][0]，L4变，改变L2[0]或者L2[1],L4不变
L4 = copy.deepcopy(L1)
# 浅拷贝，无论怎么改变L2，L5都不变
L5 = copy.copy(L1)
# Out:
# sorted(L1): ['a', 'a', 'b', 'c', 'd', 'e', 'f', 'g']
# L1: ['a', 'a', 'b', 'c', 'd', 'e', 'f', 'g']
# 复制列表：['a', 'a', 'b', 'c', 'd', 'e', 'f', 'g']
# 统计列表中a出现了2次
# B所在的位置2
# 颠倒元素的顺序:['g', 'f', 'e', 'd', 'c', 'b', 'a', 'a']
# 升序排列元素['a', 'a', 'b', 'c', 'd', 'e', 'f', 'g']
# 降序排列元素['g', 'f', 'e', 'd', 'c', 'b', 'a', 'a']
